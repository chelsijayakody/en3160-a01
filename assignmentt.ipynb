# %%
import cv2, numpy as np, matplotlib
print(cv2.__version__, np.__version__)
# Out:
# 5.0.0 2.5.3

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %%
image= cv.imread("images/q1.jpeg", cv.IMREAD_GRAYSCALE)

# %%
print(image.shape)
print(image.dtype)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 print(image.shape)
#       2 print(image.dtype)
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
import cv2

image = cv2.imread("images/q1.jpeg")

print(image.shape)
print(image.dtype)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 5
#       1 import cv2
#       2
#       3 image = cv2.imread("images/q1.jpeg")
#       4
# ----> 5 print(image.shape)
#       6 print(image.dtype)
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
print(os.getcwd())
print(os.listdir())
# Out:
# c:\Users\HP\Downloads
# ['.opera', '03_Gaussian Random Variables (Part II).pdf', '21 Batch Quiz DSP.pdf', '220247J_EN3150_A01.pdf', '230268H (1).pdf', '230268H.docx', '230268H.pdf', '230268H.xlsx', '230268H_A01_Report.pdf', '230268H_EN3150_A02_Complete_Guide.docx', '230268_EN3150_A02.pdf', '230268_EN3150_A02.tex', '230564L.pdf', '230564L_Assignment1 (1).pdf', '230564L_EN3150_A02.pdf', '2nd floor.STL', '2x frame thigh v9.stl', '3uTools_v3.18.006_Setup_x86.exe', 'AIESEC Mail - Exchange Participant Pick Up information - GCR Mora Aquatics.pdf', 'All armor parts.3mf', 'All frame parts.3mf', 'AltiumDesignerSetup_25_7_1.exe', 'another-set-of-chess-pieces-model_files', 'another-set-of-chess-pieces-model_files.zip', 'Anti Ragging Declaration 2135159.pdf', 'Apache-NetBeans-28 (1).exe', 'Apache-NetBeans-28.exe', 'Applied Stat tutorial- 5.docx', 'Applied stat tutorial-1 (15).docx', 'Applies-Stat-Tutorial-6.docx', 'arduino-ide_2.3.2_Windows_64bit.exe', 'arduino-ide_2.3.6_Windows_64bit.exe', 'Assign 1.pdf', 'Assignment - Controller design.pdf', 'assignment - System identification (1).pdf', 'assignment - System identification.pdf', 'Assignment.pdf', 'assignmentt.ipynb', 'Audacity_Installer_via_MuseHub.exe', 'Big-M_Two-Phase_New.xlsx', 'Birth certificate2.jpg', 'BraveBrowserSetup-BRV010.exe', 'C0402C332J5RECAUTO7411', 'C0402C332J5RECAUTO7411.IntLib', 'Call Me by Your Name (2017) [720p] [BluRay] [YTS.MX].torrent', 'CamScanner 02-08-2026 15.04.pdf', 'CAPAE430X565N.PcbLib', 'Carly Rae Jepsen - I Really Like You.mp3', 'ccsetup_online_setup.exe', 'ChatGPT Image Apr 27, 2026, 12_04_30 PM.png', 'ChatGPT Image Jun 8, 2026, 11_59_44 PM.png', 'ChatGPT Image Sep 2, 2025, 10_33_41 PM.png', 'ChatGPT Image Sep 6, 2026, 03_25_40 PM.png', 'ChatGPT Image Sep 7, 2026, 07_48_32 PM.png', 'ChatGPT Image Sep 7, 2026, 08_07_10 PM.png', 'ChatGPT Image Sep 7, 2026, 08_07_11 PM.png', 'chelsi-project-main', 'chelsi-project-main (1)', 'chelsi-project-main (1).zip', 'chelsi-project-main.zip', 'Codex Installer.exe', 'colorful_block_diagram.png', 'communication1.7z', 'communication1.pcapng', 'communication1.tar', 'communication1.zip', 'comparison of modulations.pdf', 'conecter1.STL', 'connecter.STL', 'Copy of Sincerely Sri Lankan Guidelines and Temlpate (1).png', 'Copy of Sincerely Sri Lankan Guidelines and Temlpate.jpg', 'Copy of Sincerely Sri Lankan Guidelines and Temlpate.png', 'Copy of SLRC 2026  (1).jpg', 'Copy of SLRC 2026  (2).jpg', 'Copy of SLRC 2026  (3).jpg', 'Copy of SLRC 2026 .jpg', 'CP210x_Universal_Windows_Driver', 'CP210x_Universal_Windows_Driver.zip', 'CP210x_Windows_Drivers', 'cupcake.png', 'CV.pdf', 'desktop.ini', 'Desktop.rar', 'doc (1).pdf', 'doc.pdf', 'DOSBox0.74-win32-installer.exe', 'drive-download-20260515T194407Z-3-001.zip', 'dsp.pdf', 'dummy-13-printable-jointed-figure-beta-files-model_files.zip', 'ECD_.pdf', 'ECD___SVF.pdf', 'EEEHA1H2R2R', 'EEEHA1H2R2R.IntLib', 'EN1020 Intake 2023 Mark Sheet.xlsx', 'en1020_2025_lecture_01.pdf', 'en1020_lecture_02.pdf', 'en1020_lecture_03.pdf', 'en1020_lecture_04.pdf', 'en1020_lecture_05.pdf', 'EN2074 – Lec 01 (1).pptx', 'EN2074 – Lec 01.pptx', 'EN2074 – Lecture 2-annotated (1).pptx', 'EN2074 – Lecture 2-annotated (2).pptx', 'EN2074 – Lecture 2-annotated.pptx', 'EN2074 – Lecture 3-annotated  (1).pptx', 'EN2074 – Lecture 3-annotated .pptx', 'EN2074 – Lecture 3.pptx', 'EN2074 – Nyquist Pulses.pptx', 'EN2074 – Pulse Amplitude Modulation (1).pptx', 'EN2074 – Pulse Amplitude Modulation.pptx', 'EN2074- Quadrature Amplitude Modulation (QAM).pptx', 'EN2074-digital modulations.pptx', 'EN2111 Analog Filters_1 (1).pdf', 'EN2111 Analog Filters_1.pdf', 'EN2111 Analog Filters_2 (1).pdf', 'EN2111 Analog Filters_2.pdf', 'EN2111 Analog PLL,LPS (1).pdf', 'EN2111 Analog PLL,LPS (2).pdf', 'EN2111 Analog PLL,LPS.pdf', 'EN2111 Coding and Verifications (1).pdf', 'EN2111 Coding and Verifications (2).pdf', 'EN2111 Coding and Verifications.pdf', 'EN2111 Feedback_1 (1).pdf', 'EN2111 Feedback_1.pdf', 'EN2111 Feedback_2 (1).pdf', 'EN2111 Feedback_2.pdf', 'EN2111 PD  ...

# %%
import os

print(os.listdir("images"))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 3
#       1 import os
#       2
# ----> 3 print(os.listdir("images"))
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'images'

# %%
import os

print(os.getcwd())
# Out:
# c:\Users\HP\Downloads

# %%
print(os.listdir())
# Out:
# ['.opera', '03_Gaussian Random Variables (Part II).pdf', '21 Batch Quiz DSP.pdf', '220247J_EN3150_A01.pdf', '230268H (1).pdf', '230268H.docx', '230268H.pdf', '230268H.xlsx', '230268H_A01_Report.pdf', '230268H_EN3150_A02_Complete_Guide.docx', '230268_EN3150_A02.pdf', '230268_EN3150_A02.tex', '230564L.pdf', '230564L_Assignment1 (1).pdf', '230564L_EN3150_A02.pdf', '2nd floor.STL', '2x frame thigh v9.stl', '3uTools_v3.18.006_Setup_x86.exe', 'AIESEC Mail - Exchange Participant Pick Up information - GCR Mora Aquatics.pdf', 'All armor parts.3mf', 'All frame parts.3mf', 'AltiumDesignerSetup_25_7_1.exe', 'another-set-of-chess-pieces-model_files', 'another-set-of-chess-pieces-model_files.zip', 'Anti Ragging Declaration 2135159.pdf', 'Apache-NetBeans-28 (1).exe', 'Apache-NetBeans-28.exe', 'Applied Stat tutorial- 5.docx', 'Applied stat tutorial-1 (15).docx', 'Applies-Stat-Tutorial-6.docx', 'arduino-ide_2.3.2_Windows_64bit.exe', 'arduino-ide_2.3.6_Windows_64bit.exe', 'Assign 1.pdf', 'Assignment - Controller design.pdf', 'assignment - System identification (1).pdf', 'assignment - System identification.pdf', 'Assignment.pdf', 'assignmentt.ipynb', 'Audacity_Installer_via_MuseHub.exe', 'Big-M_Two-Phase_New.xlsx', 'Birth certificate2.jpg', 'BraveBrowserSetup-BRV010.exe', 'C0402C332J5RECAUTO7411', 'C0402C332J5RECAUTO7411.IntLib', 'Call Me by Your Name (2017) [720p] [BluRay] [YTS.MX].torrent', 'CamScanner 02-08-2026 15.04.pdf', 'CAPAE430X565N.PcbLib', 'Carly Rae Jepsen - I Really Like You.mp3', 'ccsetup_online_setup.exe', 'ChatGPT Image Apr 27, 2026, 12_04_30 PM.png', 'ChatGPT Image Jun 8, 2026, 11_59_44 PM.png', 'ChatGPT Image Sep 2, 2025, 10_33_41 PM.png', 'ChatGPT Image Sep 6, 2026, 03_25_40 PM.png', 'ChatGPT Image Sep 7, 2026, 07_48_32 PM.png', 'ChatGPT Image Sep 7, 2026, 08_07_10 PM.png', 'ChatGPT Image Sep 7, 2026, 08_07_11 PM.png', 'chelsi-project-main', 'chelsi-project-main (1)', 'chelsi-project-main (1).zip', 'chelsi-project-main.zip', 'Codex Installer.exe', 'colorful_block_diagram.png', 'communication1.7z', 'communication1.pcapng', 'communication1.tar', 'communication1.zip', 'comparison of modulations.pdf', 'conecter1.STL', 'connecter.STL', 'Copy of Sincerely Sri Lankan Guidelines and Temlpate (1).png', 'Copy of Sincerely Sri Lankan Guidelines and Temlpate.jpg', 'Copy of Sincerely Sri Lankan Guidelines and Temlpate.png', 'Copy of SLRC 2026  (1).jpg', 'Copy of SLRC 2026  (2).jpg', 'Copy of SLRC 2026  (3).jpg', 'Copy of SLRC 2026 .jpg', 'CP210x_Universal_Windows_Driver', 'CP210x_Universal_Windows_Driver.zip', 'CP210x_Windows_Drivers', 'cupcake.png', 'CV.pdf', 'desktop.ini', 'Desktop.rar', 'doc (1).pdf', 'doc.pdf', 'DOSBox0.74-win32-installer.exe', 'drive-download-20260515T194407Z-3-001.zip', 'dsp.pdf', 'dummy-13-printable-jointed-figure-beta-files-model_files.zip', 'ECD_.pdf', 'ECD___SVF.pdf', 'EEEHA1H2R2R', 'EEEHA1H2R2R.IntLib', 'EN1020 Intake 2023 Mark Sheet.xlsx', 'en1020_2025_lecture_01.pdf', 'en1020_lecture_02.pdf', 'en1020_lecture_03.pdf', 'en1020_lecture_04.pdf', 'en1020_lecture_05.pdf', 'EN2074 – Lec 01 (1).pptx', 'EN2074 – Lec 01.pptx', 'EN2074 – Lecture 2-annotated (1).pptx', 'EN2074 – Lecture 2-annotated (2).pptx', 'EN2074 – Lecture 2-annotated.pptx', 'EN2074 – Lecture 3-annotated  (1).pptx', 'EN2074 – Lecture 3-annotated .pptx', 'EN2074 – Lecture 3.pptx', 'EN2074 – Nyquist Pulses.pptx', 'EN2074 – Pulse Amplitude Modulation (1).pptx', 'EN2074 – Pulse Amplitude Modulation.pptx', 'EN2074- Quadrature Amplitude Modulation (QAM).pptx', 'EN2074-digital modulations.pptx', 'EN2111 Analog Filters_1 (1).pdf', 'EN2111 Analog Filters_1.pdf', 'EN2111 Analog Filters_2 (1).pdf', 'EN2111 Analog Filters_2.pdf', 'EN2111 Analog PLL,LPS (1).pdf', 'EN2111 Analog PLL,LPS (2).pdf', 'EN2111 Analog PLL,LPS.pdf', 'EN2111 Coding and Verifications (1).pdf', 'EN2111 Coding and Verifications (2).pdf', 'EN2111 Coding and Verifications.pdf', 'EN2111 Feedback_1 (1).pdf', 'EN2111 Feedback_1.pdf', 'EN2111 Feedback_2 (1).pdf', 'EN2111 Feedback_2.pdf', 'EN2111 PD  ...
